# %% [markdown]
# ### Install Sempy

# %% [markdown]
# Relevant refferences:
# - [Sempy release blog](https://blog.fabric.microsoft.com/en-us/blog/semantic-link-use-fabric-notebooks-and-power-bi-datasets-for-machine-learning-data-validation-and-more/)
# - [Sempy Documentation and tutorials](https://learn.microsoft.com/en-us/fabric/data-science/semantic-link-overview)

# %%
# Install sempy package
# %pip install semantic-link
# %pip install semantic-link-labs
import sempy.fabric as fabric
import sempy_labs as labs
from sempy_labs import directlake

# Load extension 
# %load_ext sempy
# Out:
# StatementMeta(, 63073b6a-43c6-4779-b698-00db1c88a3b9, 9, Finished, Available, Finished)
# Collecting semantic-link
#   Downloading semantic_link-0.9.0-py3-none-any.whl (9.7 kB)
# Collecting semantic-link-sempy==0.9.0
#   Downloading semantic_link_sempy-0.9.0-py3-none-any.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/3.2 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 63.6 MB/s eta 0:00:00
# Collecting semantic-link-functions-geopandas==0.9.0
#   Downloading semantic_link_functions_geopandas-0.9.0-py3-none-any.whl (4.0 kB)
# Collecting semantic-link-functions-meteostat==0.9.0
#   Downloading semantic_link_functions_meteostat-0.9.0-py3-none-any.whl (4.5 kB)
# Collecting semantic-link-functions-phonenumbers==0.9.0
#   Downloading semantic_link_functions_phonenumbers-0.9.0-py3-none-any.whl (4.3 kB)
# Collecting semantic-link-functions-validators==0.9.0
#   Downloading semantic_link_functions_validators-0.9.0-py3-none-any.whl (4.7 kB)
# Collecting semantic-link-functions-holidays==0.9.0
#   Downloading semantic_link_functions_holidays-0.9.0-py3-none-any.whl (4.2 kB)
# Collecting mapclassify
#   Downloading mapclassify-2.8.1-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 kB 29.5 MB/s eta 0:00:00
# Collecting folium
#   Downloading folium-0.19.4-py2.py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 59.1 MB/s eta 0:00:00
# Collecting geopandas
#   Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.6/323.6 kB 87.9 MB/s eta 0:00:00
# Collecting holidays
#   Downloading holidays-0.66-py3-none-any.whl (791 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 791.2/791.2 kB 111.8 MB/s eta 0:00:00
# Collecting meteostat
#   Downloading meteostat-1.6.8-py3-none-any.whl (31 kB)
# Collecting phonenumbers
#   Downloading phonenumbers-8.13.54-py2.py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/2.6 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 170.0 MB/s eta 0:00:00
# Collecting validators
#   Downloading validators-0.34.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy==0.9.0->semantic-link) (0.20.1)
# Collecting setuptools>=68.2.2
#   Downloading setuptools-75.8.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 134.7 MB/s eta 0:00:00
# Collecting clr-loader>=0.2.5
#   Downloading clr_loader-0.2.7.post0-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 27.4 MB/s eta 0:00:00
# Collecting pythonnet>=3.0.1
#   Downloading pythonnet-3.0.5-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.5/297.5 kB 108.0 MB/s eta 0:00:00
# Collecting pyarrow>=12.0.1
#   Downloading pyarrow-19.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.2 MB)
#      ━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/42.2 MB 291.4 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━ 33.5/42.2 MB 276.5 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 MB 104.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.65.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy==0.9.0->semantic-link) (4.65.0)
# Collecting rich>=13.3.5
#   Downloading rich-13.9.4-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 kB 86.4 MB/s eta 0:00:00
# Collecting scikit-learn>=1.2.2
#   Downloading scikit_learn-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/13.5 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 149.2 MB/s eta 0:00:00
# Collecting cffi>=1.17
#   Downloading cffi-1.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (446 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 446.2/446.2 kB 95.9 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from rich>=13.3.5->semantic-link-sempy==0.9.0->semantic-link) (2.14.0)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 39.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from rich>=13.3.5->semantic-link-sempy==0.9.0->semantic-link) (4.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy==0.9.0->semantic-link) (3.1.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy==0.9.0->semantic-link) (1.2.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy==0.9.0->semantic-link) (1.10.1)
# Requirement already satisfied: numpy>=1.19.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy==0.9.0->semantic-link) (1.23.5)
# Requirement already satisfied: requests in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from folium->semantic-link-functions-geopandas==0.9.0->semantic-link) (2.28.2)
# Collecting xyzservices
#   Downloading xyzservices-2025.1.0-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 44.8 MB/s eta 0:00:00
# Collecting branca>=0.6.0
#   Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: jinja2>=2.9 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from folium->semantic-link-functions-geopandas==0.9.0->semantic-link) (3.1.2)
# Collecting pyproj>=3.3.0
#   Downloading pyproj-3.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 186.1 MB/s eta 0:00:00
# Collecting shapely>=2.0.0
#   Downloading shapely-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 188.2 MB/s eta 0:00:00
# Collecting pyogrio>=0.7.2
#   Downloading pyogrio-0.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/23.7 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 23.7/23.7 MB 294.2 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 138.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from geopandas->semantic-link-functions-geopandas==0.9.0->semantic-link) (1.5.3)
# Requirement already satisfied: packaging in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from geopandas->semantic-link-functions-geopandas==0.9.0->semantic-link) (22.0)
# Requirement already satisfied: python-dateutil in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from holidays->semantic-link-functions-holidays==0.9.0->semantic-link) (2.8.2)
# Collecting networkx>=2.7
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.7 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 178.3 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from meteostat->semantic-link-functions-meteostat==0.9.0->semantic-link) (2022.7.1)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from cffi>=1.17->clr-loader>=0.2.5->semantic-link-sempy==0.9.0->semantic-link) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from jinja2>=2.9->folium->semantic-link-functions-geopandas==0.9.0->semantic-link) (2.1.2)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: certifi in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pyogrio>=0.7.2->geopandas->semantic-link-functions-geopandas==0.9.0->semantic-link) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from python-dateutil->holidays->semantic-link-functions-holidays==0.9.0->semantic-link) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests->folium->semantic-link-functions-geopandas==0.9.0->semantic-link) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests->folium->semantic-link-functions-geopandas==0.9.0->semantic-link) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests->folium->semantic-link-functions-geopandas==0.9.0->semantic-link) (1.26.14)
# Installing collected packages: phonenumbers, xyzservices, validators, shapely, setuptools, pyproj, pyogrio, pyarrow, networkx, mdurl, cffi, scikit-learn, markdown-it-py, holidays, clr-loader, branca, rich, pythonnet, meteostat, mapclassify, geopandas, folium, semantic-link-sempy, semantic-link-functions-validators, semantic-link-functions-phonenumbers, semantic-link-functions-meteostat, semantic-link-functions-holidays, semantic-link-functions-geopandas, semantic-link
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.6.1
#     Not uninstalling setuptools at /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages, outside environment /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671
#     Can't uninstall 'setuptools'. No files were found to uninstall.
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 11.0.0
#     Not uninstalling pyarrow at /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages, outside environment /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671
#     Can't uninstall 'pyarrow'. No files were found to uninstall.
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.15.1
#     Not uninstalling cffi at /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages, outside environment /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671
#     Can't uninstall 'cffi'. No files were found to uninstall.
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.0
#     Not uninstalling scikit-learn at /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages, outside environment /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671
#     Can't uninstall 'scikit-learn'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lime 0.2.0.1 requires scikit-image>=0.12, which is not installed.
# azureml-core 1.49.0 requires packaging<22.0,>=20.0, but you have packaging 22.0 which is incompatible.
# azureml-core 1.49.0 requires paramiko<3.0.0,>=2.0.8, but you have paramiko 3.4.0 which is incompatible.
# Successfully installed branca-0.8.1 cffi-1.17.1 clr-loader-0.2.7.post0 folium-0.19.4 geopandas-1.0.1 holidays-0.66 mapclassify-2.8.1 markdown-it-py-3.0.0 mdurl-0.1.2 meteostat-1.6.8 networkx-3.4.2 phonenumbers-8.13.54 pyarrow-19.0.0 pyogrio-0.10.0 pyproj-3.7.0 pythonnet-3.0.5 rich-13.9.4 scikit-learn-1.6.1 semantic-link-0.9.0 semantic-link-functions-geopandas-0.9.0 semantic-link-functions-holidays-0.9.0 semantic-link-functions-meteostat-0.9.0 semantic-link-functions-phonenumbers-0.9.0 semantic-link-functions-validators-0.9.0 semantic-link-sempy-0.9.0 setuptools-75.8.0 shapely-2.0.7 validators-0.34.0 xyzservices-2025.1.0
#
# [notice] A new release of pip is available: 23.0 -> 25.0
# [notice] To update, run: /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting semantic-link-labs
#   Downloading semantic_link_labs-0.9.2-py3-none-any.whl (650 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 650.1/650.1 kB 45.0 MB/s eta 0:00:00
# Collecting polib
#   Downloading polib-1.2.0-py2.py3-none-any.whl (20 kB)
# Collecting anytree
#   Downloading anytree-2.12.1-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 25.1 MB/s eta 0:00:00
# Requirement already satisfied: semantic-link-sempy>=0.8.5 in /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671/lib/python3.10/site-packages (from semantic-link-labs) (0.9.0)
# Collecting powerbiclient
#   Downloading powerbiclient-3.1.1-py2.py3-none-any.whl (684 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 684.9/684.9 kB 101.4 MB/s eta 0:00:00
# Collecting jsonpath_ng
#   Downloading jsonpath_ng-1.7.0-py3-none-any.whl (30 kB)
# Requirement already satisfied: rich>=13.3.5 in /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671/lib/python3.10/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (13.9.4)
# Requirement already satisfied: tqdm>=4.65.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (4.65.0)
# Requirement already satisfied: pyarrow>=12.0.1 in /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671/lib/python3.10/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (19.0.0)
# Requirement already satisfied: scikit-learn>=1.2.2 in /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671/lib/python3.10/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (1.6.1)
# Requirement already satisfied: clr-loader>=0.2.5 in /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671/lib/python3.10/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (0.2.7.post0)
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (0.20.1)
# Requirement already satisfied: pythonnet>=3.0.1 in /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671/lib/python3.10/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (3.0.5)
# Requirement already satisfied: setuptools>=68.2.2 in /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671/lib/python3.10/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (75.8.0)
# Requirement already satisfied: six in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from anytree->semantic-link-labs) (1.16.0)
# Requirement already satisfied: ply in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from jsonpath_ng->semantic-link-labs) (3.11)
# Collecting jupyter-ui-poll>=0.1.2
#   Downloading jupyter_ui_poll-1.0.0-py2.py3-none-any.whl (9.1 kB)
# Requirement already satisfied: pandas in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from powerbiclient->semantic-link-labs) (1.5.3)
# Requirement already satisfied: pyspark in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from powerbiclient->semantic-link-labs) (3.3.1)
# Requirement already satisfied: msal>=1.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from powerbiclient->semantic-link-labs) (1.21.0)
# Requirement already satisfied: requests>=2.25.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from powerbiclient->semantic-link-labs) (2.28.2)
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from powerbiclient->semantic-link-labs) (8.0.4)
# Requirement already satisfied: cffi>=1.17 in /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671/lib/python3.10/site-packages (from clr-loader>=0.2.5->semantic-link-sempy>=0.8.5->semantic-link-labs) (1.17.1)
# Requirement already satisfied: traitlets>=4.3.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (4.0.7)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (3.0.7)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (6.22.0)
# Requirement already satisfied: ipython>=6.1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (8.9.0)
# Requirement already satisfied: PyJWT[crypto]<3,>=1.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from msal>=1.8.0->powerbiclient->semantic-link-labs) (2.6.0)
# Requirement already satisfied: cryptography<41,>=0.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from msal>=1.8.0->powerbiclient->semantic-link-labs) (40.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.25.1->powerbiclient->semantic-link-labs) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.25.1->powerbiclient->semantic-link-labs) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.25.1->powerbiclient->semantic-link-labs) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.25.1->powerbiclient->semantic-link-labs) (2.1.1)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from rich>=13.3.5->semantic-link-sempy>=0.8.5->semantic-link-labs) (4.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671/lib/python3.10/site-packages (from rich>=13.3.5->semantic-link-sempy>=0.8.5->semantic-link-labs) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from rich>=13.3.5->semantic-link-sempy>=0.8.5->semantic-link-labs) (2.14.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.8.5->semantic-link-labs) (3.1.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.8.5->semantic-link-labs) (1.2.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.8.5->semantic-link-labs) (1.10.1)
# Requirement already satisfied: numpy>=1.19.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.8.5->semantic-link-labs) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pandas->powerbiclient->semantic-link-labs) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pandas->powerbiclient->semantic-link-labs) (2022.7.1)
# Requirement already satisfied: py4j==0.10.9.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pyspark->powerbiclient->semantic-link-labs) (0.10.9.5)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from cffi>=1.17->clr-loader>=0.2.5->semantic-link-sempy>=0.8.5->semantic-link-labs) (2.21)
# Requirement already satisfied: psutil in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (5.9.4)
# Requirement already satisfied: tornado>=6.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (6.2)
# Requirement already satisfied: comm>=0.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.1.3)
# Requirement already satisfied: pyzmq>=20 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (25.0.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (1.5.6)
# Requirement already satisfied: packaging in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (22.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (8.1.0)
# Requirement already satisfied: debugpy>=1.6.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (1.6.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (3.0.38)
# Requirement already satisfied: decorator in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (5.1.1)
# Requirement already satisfied: stack-data in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.6.2)
# Requirement already satisfied: jedi>=0.16 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.18.2)
# Requirement already satisfied: backcall in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.2.0)
# Requirement already satisfied: pickleshare in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (4.8.0)
# Requirement already satisfied: mdurl~=0.1 in /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13.3.5->semantic-link-sempy>=0.8.5->semantic-link-labs) (0.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (3.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.7.0)
# Requirement already satisfied: wcwidth in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.2.6)
# Requirement already satisfied: asttokens>=2.1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (1.2.0)
# Requirement already satisfied: pure-eval in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.2.2)
# Installing collected packages: polib, jsonpath_ng, anytree, jupyter-ui-poll, powerbiclient, semantic-link-labs
# Successfully installed anytree-2.12.1 jsonpath_ng-1.7.0 jupyter-ui-poll-1.0.0 polib-1.2.0 powerbiclient-3.1.1 semantic-link-labs-0.9.2
#
# [notice] A new release of pip is available: 23.0 -> 25.0
# [notice] To update, run: /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Warning: PySpark kernel has been restarted to use updated packages.

# %%
# Define variables
_SemanticModelName = "test demo"
_workspace = "Dive into DirectLake"
# Out:
# StatementMeta(, 63073b6a-43c6-4779-b698-00db1c88a3b9, 11, Finished, Available, Finished)

# %% [markdown]
# # Get dictionary temperature - execute DMV
# This in specific queries a DMV operation to get the current data in cache.

# %%
# %%dax "test demo"
#
# select DIMENSION_NAME, COLUMN_ID, DICTIONARY_SIZE, DICTIONARY_TEMPERATURE, DICTIONARY_LAST_ACCESSED
# from $SYSTEM.DISCOVER_STORAGE_TABLE_COLUMNS
# order by DICTIONARY_TEMPERATURE desc
# Out:
# StatementMeta(, 63073b6a-43c6-4779-b698-00db1c88a3b9, 12, Finished, Available, Finished)
#    DIMENSION_NAME                                          COLUMN_ID  \
# 0   InternetSales                                   SalesAmount (55)
# 1         Product                                         Color (30)
# 2         Product                                         Class (36)
# 3            Date                                  CalendarYear (67)
# 4   InternetSales                                   CustomerKey (42)
# 5            Date                                       DateKey (57)
# 6   InternetSales                                  OrderDateKey (44)
# 7         Product                                    ProductKey (24)
# 8   InternetSales                                    ProductKey (43)
# 9         Product                                  StandardCost (29)
# 10        Product                                   ProductLine (35)
# 11        Product                                        Weight (34)
# 12  InternetSales                             SalesTerritoryKey (49)
# 13        Product                                         Style (37)
# 14        Product                            EnglishProductName (28)
# 15        Product                           ProductAlternateKey (25)
# 16        Product                                     SizeRange (33)
# 17           Date                               DayNumberOfYear (62)
# 18  InternetSales                          SalesOrderLineNumber (41)
# 19        Product                                          Size (32)
# 20           Date                              EnglishMonthName (64)
# 21           Date                               CalendarQuarter (66)
# 22  InternetSales                                    DueDateKey (45)
# 23  InternetSales                                   ShipDateKey (46)
# 24  InternetSales                                  PromotionKey (47)
# 25  InternetSales                                   CurrencyKey (48)
# 26        Product                           SizeUnitMeasureCode (27)
# 27  InternetSales                                 OrderQuantity (50)
# 28  InternetSales                                     UnitPrice (51)
# 29  InternetSales                                ExtendedAmount (52)
# 30  InternetSales                              SalesOrderNumber (40)
# 31           Date  RowNumber 2662979B 1795 4F74 8F37 6A1BA8059B61...
# 32  InternetSales  RowNumber 2662979B 1795 4F74 8F37 6A1BA8059B61...
# 33  InternetSales                                     TaxAmount (56)
# 34        Product                            EnglishDescription (39)
# 35  InternetSales                              TotalProductCost (54)
# 36           Date                          FullDateAlternateKey (58)
# 37           Date                               DayNumberOfWeek (59)
# 38           Date                          EnglishDayNameOfWeek (60)
# 39           Date                              DayNumberOfMonth (61)
# 40  InternetSales                           ProductStandardCost (53)
# 41           Date                              WeekNumberOfYear (63)
# 42        Product                                     ModelName (38)
# 43           Date                             MonthNumberOfYear (65)
# 44        Product                                     ListPrice (31)
# 45        Product                         ProductSubcategoryKey (26)
# 46           Date                              CalendarSemester (68)
# 47           Date                                 FiscalQuarter (69)
# 48           Date                                    FiscalYear (70)
# 49           Date                                FiscalSemester (71)
# 50        Product  RowNumber 2662979B 1795 4F74 8F37 6A1BA8059B61...
#
#     DICTIONARY_SIZE  DICTIONARY_TEMPERATURE   DICTIONARY_LAST_ACCESSED
# 0              2624               23.783319 2025-02-06 13:36:02.500000
# 1             17292               19.726997 2025-02-06 13:36:02.466667
# 2             17130               16.474792 2025-02-06 13:36:02.466667
# 3              1332               13.690388 2025-02-06 13:36:02.500000
# 4            598512               11.221868 2025-02-06 13:36:02.466667
# 5             38900                0.804587 2025-02-06 13:35:34.016667
# 6             21256                0.804587 2025-02-06 13:35:34.016667
# 7             19096                0.722685 2025-02-06 13:33:55.733333
# 8              5016                0.722685 2025-02-06 13:33:55.733333
# 9                 0                    <NA>                        NaT
# 10                0                    <NA>                        NaT
# 11                0                    <NA>                        NaT
# 12                0                    <NA>                        NaT
# 13                0                    <NA>                        NaT
# 14                0                    <NA>                        NaT
# 15                0                    <NA>                        NaT
# 16                0                    <NA>                        NaT
# 17                0                    <NA>                        NaT
# 18                0                    <NA>                        NaT
# 19                0                    <NA>                        NaT
# 20                0                    <NA>                        NaT
# 21                0                    <NA>                        NaT
# 22                0                    <NA>                        NaT
# 23                0                    <NA>                        NaT
# 24                0                    <NA>                        NaT
# 25                0                    <NA>                        NaT
# 26                0                    <NA>                        NaT
# 27                0                    <NA>                        NaT
# 28                0                    <NA>                        NaT
# 29                0                    <NA>                        NaT
# 30                0                    <NA>                        NaT
# 31              128                    <NA>                        NaT
# 32              128                    <NA>                        NaT
# 33                0                    <NA>                        NaT
# 34                0                    <NA>                        NaT
# 35                0                    <NA>                        NaT
# 36                0                    <NA>                        NaT
# 37                0                    <NA>                        NaT
# 38                0                    <NA>                        NaT
# 39                0                    <NA>                        NaT
# 40                0                    <NA>                        NaT
# 41                0                    <NA>                        NaT
# 42                0                    <NA>                        NaT
# 43                0                    <NA>                        NaT
# 44                0                    <NA>                        NaT
# 45                0                    <NA>                        NaT
# 46                0                    <NA>                        NaT
# 47                0                    <NA>                        NaT
# 48                0                    <NA>                        NaT
# 49                0                    <NA>                        NaT
# 50              128                    <NA>                        NaT

# %% [markdown]
# # Refresh operations

# %%
# Full model refresh - evict all data from cache! Be mindful that directlake will not work after running this command! 

fabric.refresh_dataset(
    workspace=_workspace,
    dataset=_SemanticModelName, 
    refresh_type= 'clearValues'
)
# docs: https://learn.microsoft.com/en-us/python/api/semantic-link-sempy/sempy.fabric?view=semantic-link-python#sempy-fabric-refresh-dataset
# Out:
# StatementMeta(, 63073b6a-43c6-4779-b698-00db1c88a3b9, 13, Finished, Available, Finished)
# 'a65c42aa-39fc-4df5-8d40-cf191e68e607'

# %%
# List the refresh requests to check if the refresh finished.
fabric.list_refresh_requests(dataset=_SemanticModelName, workspace=_workspace)
# Out:
# StatementMeta(, 63073b6a-43c6-4779-b698-00db1c88a3b9, 19, Finished, Available, Finished)
#             Id                            Request Id  \
# 0   1195246008  c8309a19-4ea5-4f93-ab10-482525217b7b
# 1   1195245005  a65c42aa-39fc-4df5-8d40-cf191e68e607
# 2   1195093253  a5e0a0d9-4184-40a8-aad9-222f7953116c
# 3   1195093218  89eed70b-bc46-48cf-b93c-0d9ade902063
# 4   1195093187  62e95a81-f6a3-4f1e-a121-21b041bb74eb
# 5   1195029849  851a435b-ddd0-498b-b7ca-fb42dea0bad8
# 6   1195027222  451ee17d-099c-4896-83f9-eef4fa2b0d43
# 7   1194656045  b898983e-bf65-4420-95b0-07952412b471
# 8   1193942192  8f40afdf-8bd3-41d7-886d-41d28d8fc03f
# 9   1193939322  a34cde9f-ed8e-4fa5-9e63-6fe9bfd41c76
# 10  1193935839  c75f3719-672e-4e87-96a6-153defc79a26
# 11  1193919647  7446fb5d-9e00-070e-d550-5cfb986d3c52
# 12  1193918483  1885ae23-70ae-4a4e-bfbc-522512ce38aa
# 13  1190041084  e2232b64-e512-40da-b780-dc29d5ccd392
# 14  1190041077  2cab0a33-e61d-42e2-9b59-583c2218f9c6
# 15  1190040968  cd9c73a6-3f51-410b-a0b9-d404c3ec7076
# 16  1190038758  0be9163e-1a11-4856-ab9a-050ece438296
# 17  1190038746  ca3acefc-0810-4348-a3fc-8396e8fb37c3
# 18  1190035136  f35add25-7e4d-4d41-84d4-3f98881c074e
# 19  1190031827  306a935f-a35c-4a76-974c-4902c184557f
#
#                          Start Time                         End Time  \
# 0  2025-02-06 13:42:09.347000+00:00 2025-02-06 13:42:13.693000+00:00
# 1  2025-02-06 13:40:38.947000+00:00 2025-02-06 13:40:44.677000+00:00
# 2  2025-02-06 11:16:49.877000+00:00 2025-02-06 11:16:54.737000+00:00
# 3  2025-02-06 11:16:30.610000+00:00 2025-02-06 11:16:34.220000+00:00
# 4  2025-02-06 11:16:16.080000+00:00 2025-02-06 11:16:20.300000+00:00
# 5  2025-02-06 10:15:33.353000+00:00 2025-02-06 10:15:59.563000+00:00
# 6  2025-02-06 10:13:20.267000+00:00 2025-02-06 10:13:23.190000+00:00
# 7  2025-02-06 04:30:12.443000+00:00 2025-02-06 04:31:46.167000+00:00
# 8  2025-02-05 15:04:44.160000+00:00 2025-02-05 15:04:54.127000+00:00
# 9  2025-02-05 15:02:35.327000+00:00 2025-02-05 15:02:40.807000+00:00
# 10 2025-02-05 15:01:35.590000+00:00 2025-02-05 15:01:40.140000+00:00
# 11 2025-02-05 14:48:26.153000+00:00 2025-02-05 14:48:33.887000+00:00
# 12 2025-02-05 14:47:59.243000+00:00 2025-02-05 14:48:04.943000+00:00
# 13 2025-02-02 18:54:46.557000+00:00 2025-02-02 18:54:52.470000+00:00
# 14 2025-02-02 18:54:27.133000+00:00 2025-02-02 18:54:29.923000+00:00
# 15 2025-02-02 18:53:45.577000+00:00 2025-02-02 18:53:51.940000+00:00
# 16 2025-02-02 18:50:54.617000+00:00 2025-02-02 18:50:59.233000+00:00
# 17 2025-02-02 18:50:45.897000+00:00 2025-02-02 18:50:48.247000+00:00
# 18 2025-02-02 18:46:44.610000+00:00 2025-02-02 18:46:49.293000+00:00
# 19 2025-02-02 18:43:22.350000+00:00 2025-02-02 18:43:22.380000+00:00
#
#          Refresh Type Service Exception Json     Status Extended Status  \
# 0      ViaEnhancedApi                    NaN  Completed       Completed
# 1      ViaEnhancedApi                    NaN  Completed       Completed
# 2      ViaEnhancedApi                    NaN  Completed       Completed
# 3      ViaEnhancedApi                    NaN  Completed       Completed
# 4      ViaEnhancedApi                    NaN  Completed       Completed
# 5      ViaEnhancedApi                    NaN  Completed       Completed
# 6      ViaEnhancedApi                    NaN  Completed       Completed
# 7           Scheduled                    NaN  Completed             NaN
# 8      ViaEnhancedApi                    NaN  Completed       Completed
# 9      ViaEnhancedApi                    NaN  Completed       Completed
# 10     ViaEnhancedApi                    NaN  Completed       Completed
# 11           OnDemand                    NaN  Completed             NaN
# 12     ViaEnhancedApi                    NaN  Completed       Completed
# 13     ViaEnhancedApi                    NaN  Completed       Completed
# 14     ViaEnhancedApi                    NaN  Completed       Completed
# 15     ViaEnhancedApi                    NaN  Completed       Completed
# 16     ViaEnhancedApi                    NaN  Completed       Completed
# 17     ViaEnhancedApi                    NaN  Completed       Completed
# 18     ViaEnhancedApi                    NaN  Completed       Completed
# 19  DirectLakeFraming                    NaN  Completed             NaN
#
#                                      Refresh Attempts
# 0   [{'attemptId': 1, 'startTime': '2025-02-06T13:...
# 1   [{'attemptId': 1, 'startTime': '2025-02-06T13:...
# 2   [{'attemptId': 1, 'startTime': '2025-02-06T11:...
# 3   [{'attemptId': 1, 'startTime': '2025-02-06T11:...
# 4   [{'attemptId': 1, 'startTime': '2025-02-06T11:...
# 5   [{'attemptId': 1, 'startTime': '2025-02-06T10:...
# 6   [{'attemptId': 1, 'startTime': '2025-02-06T10:...
# 7   [{'attemptId': 1, 'startTime': '2025-02-06T04:...
# 8   [{'attemptId': 1, 'startTime': '2025-02-05T15:...
# 9   [{'attemptId': 1, 'startTime': '2025-02-05T15:...
# 10  [{'attemptId': 1, 'startTime': '2025-02-05T15:...
# 11  [{'attemptId': 1, 'startTime': '2025-02-05T14:...
# 12  [{'attemptId': 1, 'startTime': '2025-02-05T14:...
# 13  [{'attemptId': 1, 'startTime': '2025-02-02T18:...
# 14  [{'attemptId': 1, 'startTime': '2025-02-02T18:...
# 15  [{'attemptId': 1, 'startTime': '2025-02-02T18:...
# 16  [{'attemptId': 1, 'startTime': '2025-02-02T18:...
# 17  [{'attemptId': 1, 'startTime': '2025-02-02T18:...
# 18  [{'attemptId': 1, 'startTime': '2025-02-02T18:...
# 19                                                 []

# %%
# back to ready mode - after this refresh directlake will work again! 
fabric.refresh_dataset(
    workspace=_workspace,
    dataset=_SemanticModelName, 
    refresh_type= 'automatic'
)
# Out:
# StatementMeta(, 63073b6a-43c6-4779-b698-00db1c88a3b9, 18, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# FabricHTTPException                       Traceback (most recent call last)
# Cell In[31], line 2
#       1 # back to ready mode
# ----> 2 fabric.refresh_dataset(
#       3     workspace=_workspace,
#       4     dataset=_SemanticModelName,
#       5     refresh_type= 'automatic'
#       6 )
#
# File /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671/lib/python3.10/site-packages/sempy/_utils/_log.py:357, in mds_log.<locals>.get_wrapper.<locals>.log_decorator_wrapper(*args, **kwargs)
#     354 start_time = time.perf_counter()
#     356 try:
# --> 357     result = func(*args, **kwargs)
#     359     # The invocation for get_message_dict moves after the function
#     360     # so it can access the state after the method call
#     361     message.update(extractor.get_completion_message_dict(result, arg_dict))
#
# File /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671/lib/python3.10/site-packages/sempy/fabric/_flat.py:294, in refresh_dataset(dataset, workspace, refresh_type, max_parallelism, commit_mode, retry_count, objects, apply_refresh_policy, effective_date, verbose)
#     233 """
#     234 Refresh data associated with the given dataset.
#     235
#    (...)
#     291     The refresh request id.
#     292 """
#     293 client: DatasetRestClient = _get_or_create_workspace_client(workspace).get_dataset_client(dataset)  # type: ignore
# --> 294 poll_url = client.refresh_async(refresh_type, max_parallelism, commit_mode, retry_count, objects,
#     295                                 apply_refresh_policy, effective_date, verbose)
#     297 # extract the refresh request id from the poll url
#     298 return poll_url.split("/")[-1]
#
# File /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671/lib/python3.10/site-packages/sempy/fabric/_client/_dataset_rest_client.py:98, in DatasetRestClient.refresh_async(self, refresh_type, max_parallelism, commit_mode, retry_count, objects, apply_refresh_policy, effective_date, verbose)
#      96 workspace_name = self.resolver.workspace_name
#      97 dataset_id = self.resolver.dataset_id
# ---> 98 poll_url = self.resolver.rest_api.refresh_post(dataset_id, workspace_id, workspace_name,
#      99                                                refresh_type, max_parallelism, commit_mode,
#     100                                                retry_count, objects, apply_refresh_policy, effective_date,
#     101                                                verbose)
#     102 return poll_url
#
# File /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671/lib/python3.10/site-packages/sempy/fabric/_client/_pbi_rest_api.py:147, in _PBIRestAPI.refresh_post(self, dataset_id, workspace_id, workspace_name, refresh_type, max_parallelism, commit_mode, retry_count, objects, apply_refresh_policy, effective_date, verbose)
#     144 body = _PBIRestAPI.create_refresh_body(refresh_type, max_parallelism, commit_mode, retry_count,
#     145                                        apply_refresh_policy, effective_date, objects)
#     146 json_dumps_params = json.dumps(body)
# --> 147 response = self._rest_client.post(path, data=json_dumps_params, headers={'Content-Type': 'application/json'})
#     148 poll_url = None
#     149 if getattr(response, 'headers', None) is not None:
#
# File /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671/lib/python3.10/site-packages/sempy/fabric/_client/_rest_client.py:168, in BaseRestClient.post(self, path_or_url, *args, **kwargs)
#     149 def post(self, path_or_url: str, *args, **kwargs):
#     150     """
#     151     POST request to the Fabric and PowerBI REST API.
#     152
#    (...)
#     166         The response from the REST API.
#     167     """
# --> 168     return self.request("POST", path_or_url, *args, **kwargs)
#
# File /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671/lib/python3.10/site-packages/sempy/fabric/_client/_rest_client.py:126, in BaseRestClient.request(self, method, path_or_url, *args, **kwargs)
#     123 kwargs["url"] = url
#     124 kwargs["headers"] = headers
# --> 126 return self.http.request(method, *args, **kwargs)
#
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/requests/sessions.py:708, in Session.send(self, request, **kwargs)
#     705 r.elapsed = timedelta(seconds=elapsed)
#     707 # Response manipulation hooks
# --> 708 r = dispatch_hook("response", hooks, r, **kwargs)
#     710 # Persist cookies
#     711 if r.history:
#     712
#     713     # If the hooks create history then we want those cookies too
#
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/requests/hooks.py:30, in dispatch_hook(key, hooks, hook_data, **kwargs)
#      28     hooks = [hooks]
#      29 for hook in hooks:
# ---> 30     _hook_data = hook(hook_data, **kwargs)
#      31     if _hook_data is not None:
#      32         hook_data = _hook_data
#
# File /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671/lib/python3.10/site-packages/sempy/_utils/_log.py:357, in mds_log.<locals>.get_wrapper.<locals>.log_decorator_wrapper(*args, **kwargs)
#     354 start_time = time.perf_counter()
#     356 try:
# --> 357     result = func(*args, **kwargs)
#     359     # The invocation for get_message_dict moves after the function
#     360     # so it can access the state after the method call
#     361     message.update(extractor.get_completion_message_dict(result, arg_dict))
#
# File /nfs4/pyenv-a7c3ab19-ec27-4965-94c0-1b0ad6e6a671/lib/python3.10/site-packages/sempy/fabric/_client/_rest_client.py:66, in BaseRestClient.__init__.<locals>.validate_rest_response(response, *args, **kwargs)
#      63 @log_rest_response
#      64 def validate_rest_response(response, *args, **kwargs):
#      65     if response.status_code >= 400:
# ---> 66         raise FabricHTTPException(response)
#
# FabricHTTPException: 400 Bad Request for url: https://wabi-west-europe-e-primary-redirect.analysis.windows.net/v1.0/myorg/groups/62093ad9-d736-4a4a-a328-3801bd26f2fa/datasets/901e52d3-db93-4c45-a620-db0dcd6a709f/refreshes
# Error: {"error":{"code":"InvalidRequest","message":"Invalid dataset refresh request. Another refresh request is already executing"}}
# Headers: {'Cache-Control': 'no-store, must-revalidate, no-cache', 'Pragma': 'no-cache', 'Transfer-Encoding': 'chunked', 'Content-Type': 'application/json; charset=utf-8', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'RequestId': 'fa11bdab-b523-48be-a216-7a489f32d7cf', 'Access-Control-Expose-Headers': 'RequestId', 'Date': 'Thu, 06 Feb 2025 13:42:11 GMT'}

# %%
# Refresh execution details - check for individual refresh status. 
fabric.get_refresh_execution_details(_SemanticModelName, '851a435b-ddd0-498b-b7ca-fb42dea0bad8', _workspace)
# Out:
# StatementMeta(, 71879c14-d5a5-4736-ba9e-1fb0609fe518, 79, Finished, Available, Finished)
# RefreshExecutionDetails(start_time=datetime.datetime(2025, 2, 6, 10, 15, 33, 353000, tzinfo=datetime.timezone.utc), end_time=datetime.datetime(2025, 2, 6, 10, 15, 59, 563000, tzinfo=datetime.timezone.utc), type='Automatic', commit_mode='Transactional', status='Completed', extended_status='Completed', current_refresh_type='Automatic', number_of_attempts=0, objects=           Table      Partition     Status
# 0        Product        Product  Completed
# 1  InternetSales  InternetSales  Completed
# 2           Date           Date  Completed, messages=Empty DataFrame
# Columns: [Message, Type]
# Index: [], refresh_attempts=   Attempt Id                       Start Time  \
# 0           1 2025-02-06 10:15:33.861336+00:00
#
#                           End Time  Type
# 0 2025-02-06 10:15:59.564481+00:00     0  )

# %% [markdown]
# # Refresh specific tables

# %%
# Objects to refresh, define using a dictionary
objects_to_refresh = [
    {
        "table": "InternetSales"
    },
    {
        "table": "Product"
    }
]

# Refresh the dataset
fabric.refresh_dataset(
    workspace=_workspace,
    dataset=_SemanticModelName, 
    objects=objects_to_refresh,
    refresh_type= 'automatic'
)
# Out:
# StatementMeta(, ec72bd9d-9911-4e1e-8589-a94c676e4ee2, 31, Finished, Available, Finished)
# 'fed372c2-f9be-4a67-8249-60f72a2d9ff8'

# %% [markdown]
# ### Execute Query
# Below element executes queries to load the columns related in memory

# %%
df = fabric.evaluate_measure(
    # dataset name
    _SemanticModelName,
    # measures
    ["[$ Sales]"], 
    # groupby
    ["Product[Class]"]
)
df
# Out:
# StatementMeta(, 551649c1-0069-48ab-9eb5-c22a592b30b4, 16, Finished, Available, Finished)
#   Class        $ Sales
# 0  <NA>      861774.86
# 1    H   22340591.8294
# 2    L    2133761.2238
# 3    M    4022558.4675

# %% [markdown]
# # Sempy labs

# %%
# Check potential unsupported items in semantic model
labs.directlake.show_unsupported_direct_lake_objects(dataset= _SemanticModelName, workspace= _workspace)
# Out:
# StatementMeta(, 71879c14-d5a5-4736-ba9e-1fb0609fe518, 77, Finished, Available, Finished)
# (Empty DataFrame
#  Columns: [Table Name, Type]
#  Index: [],
#  Empty DataFrame
#  Columns: [Table Name, Column Name, Type, Data Type, Source]
#  Index: [],
#  Empty DataFrame
#  Columns: [From Table, From Column, To Table, To Column, From Column Data Type, To Column Data Type]
#  Index: [])

# %%
# Check fallback reason
labs.directlake.check_fallback_reason(dataset= _SemanticModelName, workspace= _workspace)
# Out:
# StatementMeta(, 63073b6a-43c6-4779-b698-00db1c88a3b9, 16, Finished, Available, Finished)
#   Table Name  FallbackReasonID    Fallback Reason Detail
# 0       <NA>                 1  This table is not framed
# 1       <NA>                 1  This table is not framed
# 2       <NA>                 1  This table is not framed
